# %%
# !ls '/datasets/anomaly-detection/Avenue Dataset' -R
# Out:
# '/datasets/anomaly-detection/Avenue Dataset':
# testing_videos	testing_vol  training_videos  training_vol
#
# '/datasets/anomaly-detection/Avenue Dataset/testing_videos':
# 01.avi	04.avi	07.avi	10.avi	13.avi	16.avi	19.avi
# 02.avi	05.avi	08.avi	11.avi	14.avi	17.avi	20.avi
# 03.avi	06.avi	09.avi	12.avi	15.avi	18.avi	21.avi
#
# '/datasets/anomaly-detection/Avenue Dataset/testing_vol':
# vol01.mat  vol04.mat  vol07.mat  vol10.mat  vol13.mat  vol16.mat  vol19.mat
# vol02.mat  vol05.mat  vol08.mat  vol11.mat  vol14.mat  vol17.mat  vol20.mat
# vol03.mat  vol06.mat  vol09.mat  vol12.mat  vol15.mat  vol18.mat  vol21.mat
#
# '/datasets/anomaly-detection/Avenue Dataset/training_videos':
# 01.avi	03.avi	05.avi	07.avi	09.avi	11.avi	13.avi	15.avi
# 02.avi	04.avi	06.avi	08.avi	10.avi	12.avi	14.avi	16.avi
#
# '/datasets/anomaly-detection/Avenue Dataset/training_vol':
# vol01.mat  vol04.mat  vol07.mat  vol10.mat  vol13.mat  vol16.mat
# vol02.mat  vol05.mat  vol08.mat  vol11.mat  vol14.mat
# vol03.mat  vol06.mat  vol09.mat  vol12.mat  vol15.mat

# %%
import scipy.io
mat = scipy.io.loadmat('/datasets/anomaly-detection/Avenue Dataset/training_vol/vol01.mat')

# %%
mat.items()
# Out:
# dict_items([('__header__', b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Sat Nov 30 14:10:08 2013'), ('__version__', '1.0'), ('__globals__', []), ('vol', array([[[ 43,  43,  43, ...,  44,  44,  44],
#         [ 46,  47,  46, ...,  46,  46,  46],
#         [ 48,  49,  49, ...,  48,  48,  48],
#         ...,
#         [245, 243, 242, ..., 241, 242, 242],
#         [240, 239, 238, ..., 236, 236, 236],
#         [235, 234, 232, ..., 230, 231, 231]],
#
#        [[ 38,  38,  38, ...,  37,  37,  37],
#         [ 40,  40,  40, ...,  40,  40,  40],
#         [ 42,  42,  42, ...,  42,  42,  42],
#         ...,
#         [155, 154, 154, ..., 150, 149, 149],
#         [150, 150, 150, ..., 147, 147, 147],
#         [147, 148, 148, ..., 145, 145, 145]],
#
#        [[ 32,  31,  31, ...,  31,  31,  31],
#         [ 36,  37,  36, ...,  36,  35,  35],
#         [ 38,  39,  38, ...,  38,  38,  38],
#         ...,
#         [138, 136, 135, ..., 137, 137, 137],
#         [135, 133, 132, ..., 134, 134, 135],
#         [132, 131, 130, ..., 131, 131, 131]],
#
#        ...,
#
#        [[ 92,  92,  92, ...,  90,  90,  90],
#         [104, 105, 106, ..., 103, 103, 103],
#         [ 86,  87,  91, ...,  85,  85,  85],
#         ...,
#         [199, 200, 200, ..., 198, 198, 198],
#         [196, 196, 197, ..., 194, 194, 194],
#         [191, 193, 194, ..., 190, 190, 190]],
#
#        [[106, 106, 106, ..., 103, 103, 103],
#         [110, 110, 110, ..., 108, 108, 108],
#         [109, 109, 109, ..., 107, 107, 107],
#         ...,
#         [201, 202, 201, ..., 201, 201, 201],
#         [192, 192, 190, ..., 191, 191, 191],
#         [199, 199, 199, ..., 197, 197, 197]],
#
#        [[101, 100,  99, ...,  99,  99,  99],
#         [111, 110, 110, ..., 109, 109, 109],
#         [114, 114, 114, ..., 113, 113, 113],
#         ...,
#         [188, 187, 187, ..., 191, 192, 191],
#         [185, 185, 185, ..., 179, 180, 180],
#         [203, 203, 203, ..., 201, 201, 201]]], dtype=uint8))])

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6c0d6237-fce8-4a74-a541-a7cac87607e4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
